# %% [markdown]
# # SoyBean Predictions

# %%
import pandas as pd
import numpy as np
import sklearn as sl
from collections import defaultdict

# %% [markdown]
# ## Load and Transform Data

# %% [markdown]
# ### Create Column Names

# %%
Columns = ['Disease','date','plant-stand','precip','temp','hail','crop-hist','area-damaged','severity','seed-tmt',
           'germination','plant-growth','leaves','leafspots-halo','leafspots-marg','leafspots-size','leaf-shread',
           'leaf-malf','leaf-mild','stem','lodging','stem-cankers','canker-lesion','fruiting-bodies','external decay',
           'mycelium','int-discolor','sclerotia','fruit-pods','fruit spots','seed','mold-growth','seed-discolor',
           'seed-size','shriveling','roots']

# %% [markdown]
# ### Read Data

# %%
soybeansU = pd.read_csv('Soybean.csv')
soybeansU.columns = Columns
soybeansU = soybeansU.replace('?','NaN')

# %%
soybeansU.head(35) # Check to make sure it was imported prpperly
# Out:
#                   Disease date plant-stand precip temp hail crop-hist  \
# 0   diaporthe-stem-canker    4           0      2    1    0         2
# 1   diaporthe-stem-canker    3           0      2    1    0         1
# 2   diaporthe-stem-canker    3           0      2    1    0         1
# 3   diaporthe-stem-canker    6           0      2    1    0         2
# 4   diaporthe-stem-canker    5           0      2    1    0         3
# 5   diaporthe-stem-canker    5           0      2    1    0         2
# 6   diaporthe-stem-canker    4           0      2    1    1         1
# 7   diaporthe-stem-canker    6           0      2    1    0         3
# 8   diaporthe-stem-canker    4           0      2    1    0         2
# 9            charcoal-rot    6           0      0    2    0         1
# 10           charcoal-rot    4           0      0    1    1         1
# 11           charcoal-rot    3           0      0    1    0         1
# 12           charcoal-rot    6           0      0    1    1         3
# 13           charcoal-rot    6           0      0    2    0         1
# 14           charcoal-rot    5           0      0    2    1         3
# 15           charcoal-rot    6           0      0    2    1         0
# 16           charcoal-rot    4           0      0    1    0         2
# 17           charcoal-rot    3           0      0    2    0         2
# 18           charcoal-rot    5           0      0    2    1         2
# 19   rhizoctonia-root-rot    1           1      2    0    0         2
# 20   rhizoctonia-root-rot    1           1      2    0    0         1
# 21   rhizoctonia-root-rot    3           0      2    0    1         3
# 22   rhizoctonia-root-rot    0           1      2    0    0         0
# 23   rhizoctonia-root-rot    0           1      2    0    0         1
# 24   rhizoctonia-root-rot    1           1      2    0    0         3
# 25   rhizoctonia-root-rot    1           1      2    0    0         0
# 26   rhizoctonia-root-rot    2           1      2    0    0         2
# 27   rhizoctonia-root-rot    1           1      2    0    0         1
# 28   rhizoctonia-root-rot    2           1      2    0    0         1
# 29       phytophthora-rot    0           1      2    1    1         1
# 30       phytophthora-rot    1           1      2    1  NaN         3
# 31       phytophthora-rot    2           1      2    2  NaN         2
# 32       phytophthora-rot    1           1      2    0    0         2
# 33       phytophthora-rot    2           1      2    2  NaN         2
# 34       phytophthora-rot    3           1      2    1  NaN         2
#
#    area-damaged severity seed-tmt  ...  int-discolor sclerotia  fruit-pods  \
# 0             0        2        1  ...             0         0           0
# 1             0        2        1  ...             0         0           0
# 2             0        2        0  ...             0         0           0
# 3             0        1        0  ...             0         0           0
# 4             0        1        0  ...             0         0           0
# 5             0        1        1  ...             0         0           0
# 6             0        1        0  ...             0         0           0
# 7             0        1        1  ...             0         0           0
# 8             0        2        0  ...             0         0           0
# 9             3        1        1  ...             2         1           0
# 10            3        1        1  ...             2         1           0
# 11            2        1        0  ...             2         1           0
# 12            3        1        1  ...             2         1           0
# 13            3        1        1  ...             2         1           0
# 14            3        1        1  ...             2         1           0
# 15            2        1        0  ...             2         1           0
# 16            2        1        0  ...             2         1           0
# 17            2        1        0  ...             2         1           0
# 18            2        1        0  ...             2         1           0
# 19            1        2        0  ...             0         0           3
# 20            1        2        0  ...             0         0           3
# 21            1        2        0  ...             0         0           3
# 22            1        1        1  ...             0         0           3
# 23            1        2        1  ...             0         0           3
# 24            1        2        0  ...             0         0           3
# 25            1        1        0  ...             0         0           3
# 26            1        1        0  ...             0         0           3
# 27            1        2        0  ...             0         0           3
# 28            1        2        0  ...             0         0           3
# 29            1        1        0  ...             0         0           3
# 30            1      NaN      NaN  ...             0         0         NaN
# 31            1      NaN      NaN  ...             0         0         NaN
# 32            1        2        1  ...             0         0           3
# 33            1      NaN      NaN  ...             0         0         NaN
# 34            1      NaN      NaN  ...             0         0         NaN
#
#    fruit spots seed mold-growth seed-discolor seed-size shriveling roots
# 0            4    0           0             0         0          0     0
# 1            4    0           0             0         0          0     0
# 2            4    0           0             0         0          0     0
# 3            4    0           0             0         0          0     0
# 4            4    0           0             0         0          0     0
# 5            4    0           0             0         0          0     0
# 6            4    0           0             0         0          0     0
# 7            4    0           0             0         0          0     0
# 8            4    0           0             0         0          0     0
# 9            4    0           0             0         0          0     0
# 10           4    0           0             0         0          0     0
# 11           4    0           0             0         0          0     0
# 12           4    0           0             0         0          0     0
# 13           4    0           0             0         0          0     0
# 14           4    0           0             0         0          0     0
# 15           4    0           0             0         0          0     0
# 16           4    0           0             0         0          0     0
# 17           4    0           0             0         0          0     0
# 18           4    0           0             0         0          0     0
# 19           4    0           0             0         0          0     0
# 20           4    0           0             0         0          0     0
# 21           4    0           0             0         0          0     0
# 22           4    0           0             0         0          0     0
# 23           4    0           0             0         0          0     0
# 24           4    0           0             0         0          0     0
# 25           4    0           0             0         0          0     0
# 26           4    0           0             0         0          0     0
# 27           4    0           0             0         0          0     0
# 28           4    0           0             0         0          0     0
# 29           4    0           0             0         0          0     0
# 30         NaN  NaN         NaN           NaN       NaN        NaN     1
# 31         NaN  NaN         NaN           NaN       NaN        NaN     1
# 32           4    0           0             0         0          0     0
# 33         NaN  NaN         NaN           NaN       NaN        NaN     1
# 34         NaN  NaN         NaN           NaN       NaN        NaN     1
#
# [35 rows x 36 columns]

# %% [markdown]
# ### Guess Missing Values via KNN Interpolation.

# %%
diseases = soybeansU.Disease.unique()
soybeans = pd.DataFrame()

for disease in diseases:
    subset = soybeansU[soybeansU['Disease'].str.contains(disease)]
    colnames = list(subset.columns)
    for col in colnames:
        subset = subset.fillna(method = "pad")

# %%
labels = soybeansU['Disease']

# %%
diseases = ['diaporthe-stem-canker', 'charcoal-rot', 'rhizoctonia-root-rot',
       'phytophthora-rot', 'brown-stem-rot', 'powdery-mildew',
       'downy-mildew', 'brown-spot', 'bacterial-blight',
       'bacterial-pustule', 'purple-seed-stain', 'anthracnose',
       'phyllosticta-leaf-spot', 'alternarialeaf-spot',
       'frog-eye-leaf-spot', 'diaporthe-pod-&-stem-blight',
       'cyst-nematode', '2-4-d-injury', 'herbicide-injury']
# Out:
# array(['diaporthe-stem-canker', 'charcoal-rot', 'rhizoctonia-root-rot',
#        'phytophthora-rot', 'brown-stem-rot', 'powdery-mildew',
#        'downy-mildew', 'brown-spot', 'bacterial-blight',
#        'bacterial-pustule', 'purple-seed-stain', 'anthracnose',
#        'phyllosticta-leaf-spot', 'alternarialeaf-spot',
#        'frog-eye-leaf-spot', 'diaporthe-pod-&-stem-blight',
#        'cyst-nematode', '2-4-d-injury', 'herbicide-injury'], dtype=object)

# %%
#soybeans = soybeans[soybeans$]
#soybeans.describe(include = 'all')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-7fde67c1570d> in <module>
#       1 #soybeans = soybeans[soybeans$]
#       2 #soybeans.describe(include = 'all')
# ----> 3 soybeans.replace('?',NaN)
#
# NameError: name 'NaN' is not defined
